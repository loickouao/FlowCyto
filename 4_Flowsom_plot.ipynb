# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
from plotnine import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from plotnine.data import mpg
from os import listdir
from os.path import isfile, join
# %matplotlib inline

"""
df_subsampleEmb = pd.read_csv('Resultats/4_Flowsom/4_result_Dimension_Reduction.csv')  
columns = df_subsampleEmb.columns
for col in columns:
    p1 = (ggplot(df_subsampleEmb)               # defining what data to use
    + aes(x='tsne1', y='tsne2', color=col) # defining what variable to use
    + geom_point()                         # defining the type of plot to use
    + theme_minimal()                      # defining a theme (optional)
    + labs(title='tsne cells of cluster 0 (B cells), Expression '+col, x='Tsne1', y='Tsne2')
    )
    ggsave(plot=p1, filename='Resultats/4_Flowsom/cells_cluster0/Figure_5b - tsne 1000 cells of channels of_interest_'+col+'.png', dpi=100)
    print("ok "+col)
"""   

mypath = "Resultats/4_Flowsom/cells_cluster0/"
files = [f for f in listdir(mypath) if f.endswith(".png") and isfile(join(mypath, f))]
i = 1

fig = plt.figure(figsize=(18.5, 10.5))
for f in files:   
    ax1 = fig.add_subplot(3, 4, i)
    image = mpimg.imread(mypath+f)
    ax1.imshow(image)
    i = i+1

plt.show()
# Out:
# num  1
# num  2
# num  3
# num  4
# num  5
# num  6
# num  7
# num  8
# num  9
# num  10
# num  11
